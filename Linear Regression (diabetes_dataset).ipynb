# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
dataset=datasets.load_diabetes()
dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
# X = dataset.data
# y = dataset.target

# %%
dataset.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# ## EDA

# %%
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['target']=dataset.target
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %%
X = df.drop(['target'],axis=1)
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#            target
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %%
sns.pairplot(df);

# %%
fig=plt.subplots(figsize=(12,8))
sns.heatmap(X.corr(),annot=True, cmap="coolwarm");

# %% [markdown]
# ## Training a Linear Regression Model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 64   0.067136  0.050680 -0.025607 -0.040099 -0.063487 -0.059873 -0.002903
# 257 -0.027310  0.050680 -0.055785  0.025315 -0.007073 -0.023547  0.052322
# 118 -0.056370  0.050680 -0.010517  0.025315  0.023198  0.040022 -0.039719
# 287  0.045341 -0.044642 -0.006206 -0.015999  0.125019  0.125198  0.019187
# 157 -0.001882  0.050680 -0.033151 -0.018294  0.031454  0.042840 -0.013948
# ..        ...       ...       ...       ...       ...       ...       ...
# 63  -0.034575 -0.044642 -0.037463 -0.060757  0.020446  0.043466 -0.013948
# 326  0.045341  0.050680 -0.008362 -0.033214 -0.007073  0.001191 -0.039719
# 337  0.019913  0.050680 -0.012673  0.070073 -0.011201  0.007141 -0.039719
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# 351 -0.085430  0.050680 -0.040696 -0.033214 -0.081374 -0.069580 -0.006584
#
#            s4        s5        s6
# 64  -0.039493 -0.019197  0.011349
# 257 -0.039493 -0.005145 -0.050783
# 118  0.034309  0.020612  0.056912
# 287  0.034309  0.032433 -0.005220
# 157  0.019917  0.010226  0.027917
# ..        ...       ...       ...
# 63  -0.002592 -0.030751 -0.071494
# 326  0.034309  0.029936  0.027917
# 337  0.034309  0.005384  0.003064
# 11   0.071210 -0.096433 -0.059067
# 351 -0.039493 -0.057800 -0.042499
#
# [353 rows x 10 columns]

# %%
y_train
# Out:
# array([ 71.,  63., 179., 219.,  84.,  70., 200.,  42.,  77.,  99., 249.,
#        230., 196., 163.,  75., 128.,  97.,  90., 171.,  71., 185., 220.,
#        237.,  95.,  39., 142.,  52., 341., 127., 144.,  73.,  37., 127.,
#        182., 235.,  97.,  57.,  55., 132., 311., 189.,  68.,  81.,  96.,
#        142., 264.,  77., 173., 310., 196.,  51.,  88., 109., 252., 166.,
#         55.,  39., 332., 151.,  63., 248., 214.,  91., 243.,  48., 220.,
#         96., 246., 310.,  98., 270., 181., 252.,  53., 121., 139.,  47.,
#         61., 268.,  67., 217., 103.,  81., 164., 153.,  85., 277., 192.,
#        206., 283., 233., 248.,  96.,  86.,  74., 198.,  87., 116.,  85.,
#         78.,  88.,  63., 200., 246.,  58.,  68., 200., 191., 109., 177.,
#        172.,  83., 272., 122., 210., 141., 200., 163.,  89.,  66., 136.,
#        261., 138., 114., 198., 111., 128.,  60., 141., 115., 195., 225.,
#        232., 295., 123., 229.,  74., 102., 182., 276.,  65.,  75., 181.,
#        302.,  64., 131., 102., 288.,  87.,  84., 221.,  40., 102., 220.,
#        158.,  64.,  72., 202., 263., 219., 243., 277.,  53., 109.,  50.,
#        139., 104.,  66., 120.,  93., 155., 242., 152., 248., 167.,  68.,
#         61., 138.,  31.,  42., 155., 143.,  89.,  94., 116., 259., 182.,
#        259., 150., 140., 137.,  88., 101., 244., 180., 150., 292., 168.,
#         65., 174., 201.,  96.,  48., 202., 178., 144.,  72., 160., 113.,
#        268.,  97., 147., 161., 275.,  70.,  84., 279.,  65., 185., 233.,
#         72.,  77., 107., 265., 150.,  59., 212., 235., 265., 306., 200.,
#         52., 121., 296., 124., 183.,  85., 174.,  90.,  90., 310., 124.,
#        245.,  49., 126., 233., 132., 158., 190., 214.,  77., 202., 131.,
#        187., 270., 262.,  71., 308., 200.,  88., 129., 303., 118., 236.,
#        216., 146., 206., 131., 297.,  48.,  93., 170., 101., 280.,  65.,
#         53., 142., 151., 293., 230., 178., 175., 283., 110., 101., 129.,
#        209., 178., 242., 292., 109., 222., 258., 241., 118., 321., 275.,
#        151., 275.,  49., 237., 135., 257.,  55., 198.,  63., 191., 156.,
#         83., 214.,  52., 145., 262.,  53.,  69., 113., 144., 150., 170.,
#        273.,  99.,  94., 215.,  78., 259., 170.,  55., 113., 197.,  85.,
#         59.,  95., 142.,  72.,  43.,  97., 104.,  91.,  78., 220., 125.,
#        111., 178., 107., 100.,  69.,  42., 134., 128., 131.,  91.,  69.,
#         71.])

# %% [markdown]
# # Training model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# r2 score
print(model.score(X_test,y_test)*100)
# Out:
# 56.51498318703951

# %% [markdown]
# ## Model Evaluate

# %% [markdown]
# ![39_blog_image_1.png](attachment:39_blog_image_1.png)

# %%
# bo =interception
model.intercept_
# Out:
# 151.70363445605867

# %%
# Coefficients= b1,b2,...,bn
model.coef_
# Out:
# array([  -9.41968901, -252.58184546,  534.64170867,  307.38673495,
#        -600.46749221,  318.56697568,   61.47570019,  193.13448206,
#         703.51327421,   34.18660706])

# %%
# coefficientlari daha iyi gostermek icin DF yapiyoruz
coeff_df = pd.DataFrame(model.coef_, index=X.columns, columns=["Coefficient"])
coeff_df
# Out:
#      Coefficient
# age    -9.419689
# sex  -252.581845
# bmi   534.641709
# bp    307.386735
# s1   -600.467492
# s2    318.566976
# s3     61.475700
# s4    193.134482
# s5    703.513274
# s6     34.186607

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([116.137549  , 125.9251187 , 253.2373469 , 120.73730687,
#        197.87637356, 173.18416247, 228.40887015, 130.2703026 ,
#        228.92000033,  74.18109735,  94.05871263, 189.39225778,
#        109.64305873, 170.57369936, 103.0818814 , 231.92522621,
#        108.55266013, 149.20249369, 232.31168983,  82.72541526,
#        186.87154143, 101.36687713, 217.46875565,  66.37155165,
#        123.28514437, 143.83081651, 163.34941826, 123.37701048,
#        147.75453894,  73.05344081, 144.58614106, 118.45462607,
#        175.24790162, 130.34689062,  70.67871411, 240.87278794,
#        152.86346749, 136.33476967,  65.79417365, 194.64771106,
#        157.77858229,  93.00667929, 120.10318201, 285.52149491,
#        241.86175966,  98.96768695, 103.04121301, 269.99085349,
#        170.40092915, 199.3141372 ,  94.64958986, 145.79507546,
#         94.58240191, 121.23731838,  77.37411291, 188.57894872,
#         84.77760341, 182.74892733, 166.94627461, 157.12540392,
#        106.3731781 ,  79.30717366,  34.82900387, 255.75840352,
#        173.41722638, 115.5956901 , 145.53984553, 122.64200169,
#         78.01216798, 209.70595706, 123.373198  , 231.51798194,
#        250.46345217, 228.23067105, 167.0181958 , 280.81126309,
#        193.47820023, 208.16774758, 295.53859663,  97.07244568,
#        132.79961293, 154.56798865, 120.11975165, 102.98472478,
#         69.2460695 ,  86.22407492, 166.87265887, 128.70374265,
#        223.93172961])

# %%
fig=plt.subplots(figsize=(10,6))
plt.scatter(y_test,y_pred);

# %%
fig=plt.subplots(figsize=(10,6))
sns.distplot((y_test-y_pred), bins=50);

# %%
y_pred_train=model.predict(X_train)

# %% [markdown]
# ## Evaluation metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    r2score = r2_score(actual, pred)
    print(f"R2 Score: {r2score}",
          f"Mean Absolute Error(MAE): {mae}",
          f"Mean Square Error(MSE): {mse}",
          f"Root Mean Square Error(RMSE): {rmse}",sep="\n")

# %%
eval_metrics(y_test, y_pred)
# Out:
# R2 Score: 0.5651498318703951
# Mean Absolute Error(MAE): 42.43427752202369
# Mean Square Error(MSE): 2778.58387553074
# Root Mean Square Error(RMSE): 52.712274429498294

# %%
eval_metrics(y_train, y_pred_train)
# Out:
# R2 Score: 0.5029361223594984
# Mean Absolute Error(MAE): 43.48817401637937
# Mean Square Error(MSE): 2889.2360345633087
# Root Mean Square Error(RMSE): 53.751614250767474

# %% [markdown]
# # Distribution of Residuals

# %%
from yellowbrick.regressor import ResidualsPlot

# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                 # Finalize and render the figure

# Residuals: Actual ve Prediction arasindaki hata payi

# %%
from yellowbrick.regressor import PredictionError

# Instantiate the linear model and visualizer
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                 # Finalize and render the figure
