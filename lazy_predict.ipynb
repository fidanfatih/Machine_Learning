# %%
import seaborn as sns
from sklearn.model_selection import train_test_split

df=sns.load_dataset("iris")
X=df.drop(["species"], axis=1)
y=df["species"]
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit (X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 43.84it/s]
# [08:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00    None      1.00
# LabelSpreading                     1.00               1.00    None      1.00
# XGBClassifier                      1.00               1.00    None      1.00
# SVC                                1.00               1.00    None      1.00
# RandomForestClassifier             1.00               1.00    None      1.00
# QuadraticDiscriminantAnalysis      1.00               1.00    None      1.00
# NuSVC                              1.00               1.00    None      1.00
# LogisticRegression                 1.00               1.00    None      1.00
# BaggingClassifier                  1.00               1.00    None      1.00
# LinearDiscriminantAnalysis         1.00               1.00    None      1.00
# LinearSVC                          1.00               1.00    None      1.00
# LabelPropagation                   1.00               1.00    None      1.00
# KNeighborsClassifier               1.00               1.00    None      1.00
# GaussianNB                         1.00               1.00    None      1.00
# ExtraTreesClassifier               1.00               1.00    None      1.00
# ExtraTreeClassifier                1.00               1.00    None      1.00
# DecisionTreeClassifier             1.00               1.00    None      1.00
# LGBMClassifier                     1.00               1.00    None      1.00
# SGDClassifier                      0.97               0.97    None      0.97
# CalibratedClassifierCV             0.95               0.94    None      0.95
# PassiveAggressiveClassifier        0.92               0.91    None      0.92
# Perceptron                         0.87               0.86    None      0.87
# NearestCentroid                    0.87               0.85    None      0.87
# RidgeClassifier                    0.87               0.85    None      0.87
# RidgeClassifierCV                  0.87               0.85    None      0.87
# BernoulliNB                        0.84               0.82    None      0.83
# DummyClassifier                    0.37               0.36    None      0.38
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.07
# LabelSpreading                       0.01
# XGBClassifier                        0.08
# SVC                                  0.01
# RandomForestClassifier               0.15
# QuadraticDiscriminantAnalysis        0.01
# NuSVC                                0.01
# LogisticRegression                   0.01
# BaggingClassifier                    0.02
# LinearDiscriminantAnalysis           0.01
# LinearSVC                            0.01
# LabelPropagation                     0.01
# KNeighborsClassifier                 0.01
# GaussianNB                           0.01
# ExtraTreesClassifier                 0.08
# ExtraTreeClassifier                  0.01
# DecisionTreeClassifier               0.01
# LGBMClassifier                       0.06
# SGDClassifier                        0.01
# CalibratedClassifierCV               0.04
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# NearestCentroid                      0.01
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# BernoulliNB                          0.01
# DummyClassifier                      0.01
